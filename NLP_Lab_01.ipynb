# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkatpotla33/NLP-Lab/blob/main/NLP_Lab_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Remove Special Characters in the given text**

# %%
# remove Special Characters in the given text

def remove_special_char(text):
    ans = " "
    for char in text:
        if char.isalnum() or char.isspace():
            ans += char
        return ans

input_text= "this is an example @ text ^ for texing%!"
output_text= remove_special_char(input_text)
print(output_text)
# Out:
#  t
